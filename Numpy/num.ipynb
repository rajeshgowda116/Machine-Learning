# %% [markdown]
# # 1-D Arry

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %% [markdown]
# # 2-D Array

# %%
import numpy as np 
a=np.array([[1,2,3],[4,5,6]])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]
