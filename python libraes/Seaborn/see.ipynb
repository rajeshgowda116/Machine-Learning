# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
png=sns.load_dataset("penguins")
png.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
png['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
png['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("ticks")
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("white")
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("dark")
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("whitegrid")
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style("darkgrid")

sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_context('poster')
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_context('talk')
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_context('paper')
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_context('notebook')
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island',palette='Set1')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_context('talk')
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island',palette='Set2')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_context('talk')
sns.scatterplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island',palette='Set3')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=png ,x='species',y='body_mass_g',hue='island',style='sex',alpha=0.5)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data=png ,x='species',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data=png ,x='species',y='body_mass_g',hue='island',dodge='True')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data=png ,x='species',y='body_mass_g',hue='island',dodge='True',jitter=True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.swarmplot(data=png ,x='species',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.set_context('notebook')
sns.histplot(data=png ,x='body_mass_g',hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.set_context('notebook')
sns.histplot(data=png ,x='body_mass_g',hue='sex',multiple='stack')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.regplot(data=png,x='flipper_length_mm',y='body_mass_g',color='green')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style('whitegrid')
sns.lineplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island',style='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.jointplot(data=png,x='flipper_length_mm',y='body_mass_g')

# %%
sns.jointplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island')

# %%
sns.jointplot(data=png,x='flipper_length_mm',y='body_mass_g',hue='island',kind='kde')

# %%
sns.jointplot(data=png,x='flipper_length_mm',y='body_mass_g',kind='reg')

# %%
sns.barplot(data=png,x='species',y='body_mass_g',hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(data=png,x='species',y='body_mass_g',hue='sex',estimator=np.sum)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.countplot(data=png,x='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.boxplot(data=png,x='species',y='body_mass_g',hue='island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data=png,x='species',y='body_mass_g',hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.kdeplot(data=png,x='body_mass_g',hue='sex',fill=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
png.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
columns=['bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g']
png[columns].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(data=png[columns].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(data=png[columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.rugplot(data=png,x='species',y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.pairplot(data=png,hue='sex')
